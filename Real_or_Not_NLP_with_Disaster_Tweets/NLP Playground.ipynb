# %%
import re
import string

from nltk.corpus import stopwords  
from nltk.tokenize import word_tokenize 

# %pip install textblob
from textblob import TextBlob

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# import nltk
# nltk.download('punkt')

# %%
"""
File that contain all the util functions for data preprocessing and more
"""
import pandas as pd 


DATA_PATH = './data/'

X = pd.read_csv(DATA_PATH+'train.csv', index_col= 0)
Y = pd.read_csv(DATA_PATH+'test.csv', index_col= 0)

# %%
X.head()
# Out:
#    keyword location                                               text  target
# id
# 1      NaN      NaN  Our Deeds are the Reason of this #earthquake M...       1
# 4      NaN      NaN             Forest fire near La Ronge Sask. Canada       1
# 5      NaN      NaN  All residents asked to 'shelter in place' are ...       1
# 6      NaN      NaN  13,000 people receive #wildfires evacuation or...       1
# 7      NaN      NaN  Just got sent this photo from Ruby #Alaska as ...       1

# %%
Y.head()
# Out:
#    keyword location                                               text
# id
# 0      NaN      NaN                 Just happened a terrible car crash
# 2      NaN      NaN  Heard about #earthquake is different cities, s...
# 3      NaN      NaN  there is a forest fire at spot pond, geese are...
# 9      NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
def preprocess(df):
    """
    :param DataFrame: Data frame to preprocess
    :return Data frame: Data frame with preprocessed data
    """
    stop_words = set(stopwords.words('english')) 
    def stopwords_p(w):
        l = []
        for i in w:
            if i in stop_words:
                pass
            else:
                # Removing puntuation
                #i = "".join([char for char in i if char not in string.punctuation])
                i = re.sub('[^a-zA-Z0-9]', '', i)
                i = i.lower()
                if len(i) > 0:
                    l.append(i)
        return l
                
    df['text_prep'] = df['text'].apply(lambda w: word_tokenize(w))
    df['text_prep'] = df['text_prep'].apply(lambda w: stopwords_p(w))
    return df
train = preprocess(X)
test = preprocess(Y)

# %%
train = shuffle(train)
train.head()
# Out:
#           keyword                  location  \
# id
# 7761       police                       NaN
# 7670        panic  Palm Bay, FL (Kissimmee)
# 583         arson                    EARTH
# 7689        panic                    Narnia
# 9888  traumatised                Londonstan
#
#                                                    text  target  \
# id
# 7761  Police expand search for missing pregnant woma...       0
# 7670  Panic over: Patient in Alabama tests negative ...       1
# 583   Owner of Chicago-Area Gay Bar Admits to Arson ...       0
# 7689  I added a video to a @YouTube playlist http://...       0
# 9888  ÛÏ@_keits: @LIVA_GOTTA get a gold chain you'l...       0
#
#                                               text_prep
# id
# 7761  [police, expand, search, missing, pregnant, wo...
# 7670  [panic, patient, alabama, tests, negative, ebo...
# 583   [owner, chicagoarea, gay, bar, admits, arson, ...
# 7689  [i, added, video, youtube, playlist, http, tco...
# 9888  [keits, livagotta, get, gold, chain, ll, under...

# %%
test.head()
# Out:
#    keyword location                                               text  \
# id
# 0      NaN      NaN                 Just happened a terrible car crash
# 2      NaN      NaN  Heard about #earthquake is different cities, s...
# 3      NaN      NaN  there is a forest fire at spot pond, geese are...
# 9      NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan
#
#                                             text_prep
# id
# 0              [just, happened, terrible, car, crash]
# 2   [heard, earthquake, different, cities, stay, s...
# 3   [forest, fire, spot, pond, geese, fleeing, acr...
# 9          [apocalypse, lighting, spokane, wildfires]
# 11      [typhoon, soudelor, kills, 28, china, taiwan]

# %% [markdown]
# <h1>Model generation</h1>

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(train.text)]
model = Doc2Vec(documents, vector_size=256, window=4, min_count=0, workers=4)

# %%
train['x'] = train['text_prep'].apply(lambda x: model.infer_vector(x))
train.head()
# Out:
# <ipython-input-38-48a110acb086>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['x'] = train['text_prep'].apply(lambda x: model.infer_vector(x))
#           keyword                  location  \
# id
# 7761       police                       NaN
# 7670        panic  Palm Bay, FL (Kissimmee)
# 583         arson                    EARTH
# 7689        panic                    Narnia
# 9888  traumatised                Londonstan
#
#                                                    text  target  \
# id
# 7761  Police expand search for missing pregnant woma...       0
# 7670  Panic over: Patient in Alabama tests negative ...       1
# 583   Owner of Chicago-Area Gay Bar Admits to Arson ...       0
# 7689  I added a video to a @YouTube playlist http://...       0
# 9888  ÛÏ@_keits: @LIVA_GOTTA get a gold chain you'l...       0
#
#                                               text_prep  \
# id
# 7761  [police, expand, search, missing, pregnant, wo...
# 7670  [panic, patient, alabama, tests, negative, ebo...
# 583   [owner, chicagoarea, gay, bar, admits, arson, ...
# 7689  [i, added, video, youtube, playlist, http, tco...
# 9888  [keits, livagotta, get, gold, chain, ll, under...
#
#                                                       x
# id
# 7761  [-0.007308758, 0.005901744, 0.0036629573, 0.00...
# 7670  [-0.019752247, 0.014266182, 0.010357015, 0.009...
# 583   [-0.010665309, 0.010349484, 0.00755486, 0.0057...
# 7689  [-0.0047078, 0.004301085, 0.004400423, 0.00467...
# 9888  [-0.011215143, 0.008989504, 0.0096160155, 0.00...

# %%
ind_train = train.index.to_list()
ind_train
# Out:
# [7761,
#  7670,
#  583,
#  7689,
#  9888,
#  4682,
#  4715,
#  3487,
#  3281,
#  744,
#  314,
#  1989,
#  6961,
#  8708,
#  8297,
#  3566,
#  8009,
#  5560,
#  4700,
#  6466,
#  5908,
#  6933,
#  298,
#  5445,
#  7463,
#  2687,
#  8394,
#  1201,
#  9062,
#  5092,
#  3643,
#  7356,
#  10385,
#  9701,
#  4086,
#  5884,
#  8938,
#  3899,
#  5085,
#  2941,
#  9732,
#  9387,
#  4849,
#  3980,
#  361,
#  7934,
#  2963,
#  1613,
#  4499,
#  2414,
#  7372,
#  8966,
#  7129,
#  7285,
#  2793,
#  4430,
#  5222,
#  6841,
#  3841,
#  8606,
#  5412,
#  625,
#  870,
#  8135,
#  7517,
#  4457,
#  4688,
#  9221,
#  4276,
#  2998,
#  2158,
#  5315,
#  6268,
#  9225,
#  9089,
#  7456,
#  6565,
#  3982,
#  3543,
#  9806,
#  407,
#  8106,
#  2517,
#  7080,
#  4641,
#  6208,
#  3125,
#  6737,
#  687,
#  6811,
#  527,
#  9731,
#  10415,
#  5018,
#  380,
#  1709,
#  2792,
#  9595,
#  1514,
#  9047,
#  8817,
#  6631,
#  5673,
#  9435,
#  53,
#  638,
#  6956,
#  3036,
#  3145,
#  4948,
#  568,
#  8767,
#  9395,
#  1350,
#  5032,
#  9087,
#  6171,
#  982,
#  5098,
#  249,
#  7821,
#  849,
#  6134,
#  2555,
#  3499,
#  9669,
#  10331,
#  1590,
#  2970,
#  316,
#  1051,
#  1052,
#  10448,
#  4550,
#  1181,
#  451,
#  6138,
#  9016,
#  5525,
#  6597,
#  5575,
#  3162,
#  1990,
#  4934,
#  7943,
#  7108,
#  6758,
#  977,
#  7330,
#  10028,
#  9341,
#  4898,
#  9233,
#  2267,
#  1832,
#  5921,
#  8287,
#  1117,
#  9055,
#  1459,
#  592,
#  7357,
#  2045,
#  7408,
#  355,
#  9616,
#  9652,
#  3165,
#  3237,
#  9934,
#  7938,
#  4406,
#  5359,
#  4556,
#  3686,
#  6824,
#  614,
#  5283,
#  1661,
#  4878,
#  891,
#  1297,
#  5162,
#  1062,
#  3047,
#  7039,
#  8863,
#  158,
#  10696,
#  6974,
#  9533,
#  8906,
#  6499,
#  4257,
#  2458,
#  3111,
#  1691,
#  738,
#  126,
#  2372,
#  5627,
#  1532,
#  6033,
#  6216,
#  9375,
#  7679,
#  5197,
#  4609,
#  2081,
#  10186,
#  2402,
#  3523,
#  4427,
#  556,
#  6427,
#  4309,
#  9673,
#  9868,
#  5704,
#  3830,
#  4274,
#  10142,
#  2516,
#  6430,
#  6247,
#  218,
#  2990,
#  4398,
#  5280,
#  7889,
#  7553,
#  6382,
#  10241,
#  4092,
#  3015,
#  8371,
#  6434,
#  5581,
#  3825,
#  2898,
#  10173,
#  10748,
#  4799,
#  7475,
#  6130,
#  1967,
#  9482,
#  8639,
#  2258,
#  8294,
#  481,
#  9886,
#  2275,
#  8933,
#  406,
#  1861,
#  7065,
#  2420,
#  7012,
#  1054,
#  6953,
#  838,
#  8972,
#  7437,
#  7535,
#  5805,
#  10378,
#  9813,
#  455,
#  2171,
#  3717,
#  6292,
#  5371,
#  799,
#  7365,
#  5029,
#  5894,
#  9343,
#  10498,
#  10795,
#  3828,
#  10559,
#  8740,
#  10009,
#  7659,
#  7924,
#  3387,
#  9842,
#  2884,
#  3493,
#  9753,
#  2000,
#  2300,
#  8498,
#  9131,
#  5223,
#  10835,
#  5519,
#  10000,
#  8993,
#  796,
#  6711,
#  7525,
#  2872,
#  3411,
#  3726,
#  2948,
#  4877,
#  9192,
#  840,
#  5004,
#  4141,
#  7163,
#  4084,
#  10372,
#  2959,
#  4060,
#  251,
#  85,
#  608,
#  3775,
#  10540,
#  1759,
#  9465,
#  4306,
#  3565,
#  3086,
#  8261,
#  6928,
#  9470,
#  5052,
#  6714,
#  6932,
#  6069,
#  3658,
#  2953,
#  2642,
#  23,
#  1772,
#  8067,
#  7970,
#  3924,
#  3147,
#  10431,
#  9367,
#  211,
#  4094,
#  9248,
#  4971,
#  4503,
#  636,
#  10730,
#  10522,
#  10610,
#  1890,
#  4872,
#  4847,
#  2947,
#  9989,
#  4363,
#  9209,
#  1533,
#  3919,
#  6165,
#  3984,
#  4382,
#  212,
#  8036,
#  5059,
#  981,
#  5461,
#  10414,
#  8315,
#  1073,
#  1562,
#  5218,
#  1939,
#  6058,
#  4332,
#  4980,
#  2585,
#  6583,
#  1509,
#  2696,
#  10189,
#  5909,
#  3260,
#  10620,
#  4568,
#  4307,
#  653,
#  3152,
#  8763,
#  7001,
#  8,
#  6744,
#  9571,
#  5848,
#  2421,
#  9242,
#  9080,
#  170,
#  4072,
#  2119,
#  4413,
#  3727,
#  19,
#  2505,
#  3104,
#  2829,
#  5423,
#  4253,
#  7179,
#  496,
#  1994,
#  3432,
#  7261,
#  1942,
#  4588,
#  6203,
#  9651,
#  3085,
#  4265,
#  3625,
#  7877,
#  1487,
#  9119,
#  1860,
#  10035,
#  5716,
#  1900,
#  542,
#  10036,
#  9960,
#  10029,
#  5837,
#  8856,
#  6453,
#  4189,
#  289,
#  4055,
#  5482,
#  9002,
#  7097,
#  10210,
#  5104,
#  7158,
#  7159,
#  5539,
#  8453,
#  4480,
#  8684,
#  2992,
#  8685,
#  735,
#  9294,
#  1302,
#  1226,
#  8487,
#  6514,
#  848,
#  6346,
#  10429,
#  5668,
#  8706,
#  8209,
#  2336,
#  1622,
#  3022,
#  6775,
#  9052,
#  9976,
#  9307,
#  10710,
#  4810,
#  2126,
#  720,
#  7392,
#  2395,
#  6988,
#  6945,
#  1824,
#  3527,
#  8006,
#  185,
#  10520,
#  7230,
#  7598,
#  7593,
#  2991,
#  4159,
#  7613,
#  6776,
#  10468,
#  4525,
#  9143,
#  942,
#  10735,
#  7649,
#  4958,
#  297,
#  2471,
#  2238,
#  6670,
#  7299,
#  2787,
#  9244,
#  3013,
#  1878,
#  9654,
#  9610,
#  578,
#  2050,
#  902,
#  1739,
#  5331,
#  1963,
#  8176,
#  5999,
#  10275,
#  9510,
#  8620,
#  1232,
#  4896,
#  3176,
#  6511,
#  624,
#  8415,
#  2071,
#  8742,
#  9484,
#  5957,
#  4018,
#  5892,
#  7337,
#  8660,
#  2621,
#  7075,
#  10545,
#  9639,
#  10660,
#  1240,
#  3221,
#  10375,
#  2797,
#  1405,
#  4104,
#  3848,
#  9441,
#  2266,
#  7703,
#  5978,
#  10565,
#  6396,
#  5943,
#  6668,
#  8111,
#  1885,
#  6223,
#  4065,
#  4488,
#  5410,
#  9941,
#  3492,
#  2932,
#  3860,
#  6510,
#  9028,
#  7992,
#  7560,
#  878,
#  8039,
#  3676,
#  8324,
#  998,
#  7345,
#  10206,
#  8150,
#  3048,
#  7801,
#  3011,
#  1209,
#  3016,
#  5179,
#  1505,
#  3889,
#  1275,
#  8785,
#  10081,
#  4791,
#  10676,
#  9779,
#  6746,
#  8693,
#  2136,
#  3647,
#  5501,
#  886,
#  1873,
#  9638,
#  8002,
#  4541,
#  7544,
#  3954,
#  1901,
#  9874,
#  9290,
#  9486,
#  4095,
#  4465,
#  9402,
#  10612,
#  6596,
#  9053,
#  8109,
#  3154,
#  9360,
#  10290,
#  5068,
#  5074,
#  1780,
#  3787,
#  6007,
#  7578,
#  4694,
#  4166,
#  798,
#  944,
#  672,
#  10819,
#  175,
#  2924,
#  8250,
#  2359,
#  1745,
#  5101,
#  2860,
#  2282,
#  4119,
#  8673,
#  165,
#  5677,
#  7078,
#  9537,
#  6467,
#  8475,
#  4882,
#  8903,
#  6914,
#  8500,
#  10117,
#  3299,
#  7378,
#  5814,
#  5467,
#  5082,
#  9810,
#  6614,
#  3163,
#  9054,
#  1455,
#  9148,
#  1393,
#  931,
#  10270,
#  9553,
#  3833,
#  8296,
#  9762,
#  9373,
#  436,
#  5791,
#  6195,
#  4021,
#  3029,
#  5717,
#  8961,
#  1669,
#  1307,
#  7111,
#  6644,
#  3862,
#  4146,
#  6127,
#  946,
#  6191,
#  9752,
#  5076,
#  930,
#  1950,
#  10737,
#  5962,
#  5989,
#  9038,
#  3550,
#  10724,
#  2608,
#  440,
#  4929,
#  10100,
#  1321,
#  3875,
#  5301,
#  9128,
#  10705,
#  10729,
#  10827,
#  10168,
#  5663,
#  6990,
#  5492,
#  7047,
#  9577,
#  2863,
#  8247,
#  1074,
#  4644,
#  1383,
#  6937,
#  7881,
#  3752,
#  8709,
#  2570,
#  8875,
#  8458,
#  1692,
#  976,
#  6244,
#  2036,
#  5041,
#  10405,
#  6076,
#  916,
#  6241,
#  1591,
#  9197,
#  10553,
#  2625,
#  4627,
#  10183,
#  10515,
#  3275,
#  10536,
#  6844,
#  8013,
#  1547,
#  1684,
#  3604,
#  4735,
#  7547,
#  9820,
#  2020,
#  8102,
#  8835,
#  2498,
#  4173,
#  1611,
#  656,
#  5958,
#  5690,
#  444,
#  5206,
#  4646,
#  8161,
#  2191,
#  4737,
#  9466,
#  7344,
#  7878,
#  4564,
#  2943,
#  4356,
#  6678,
#  8855,
#  10449,
#  1252,
#  7972,
#  667,
#  5148,
#  7906,
#  1217,
#  5960,
#  3700,
#  6774,
#  3283,
#  7842,
#  7891,
#  6417,
#  5324,
#  10606,
#  4325,
#  10284,
#  1975,
#  8704,
#  7334,
#  4797,
#  419,
#  1020,
#  2694,
#  4903,
#  8664,
#  841,
#  2491,
#  3917,
#  9949,
#  3990,
#  9504,
#  9632,
#  2442,
#  1229,
#  9351,
#  2913,
#  9135,
#  9262,
#  10325,
#  4408,
#  7545,
#  8476,
#  6935,
#  8542,
#  2785,
#  6830,
#  4154,
#  5462,
#  5291,
#  3935,
#  6055,
#  276,
#  8440,
#  240,
#  4716,
#  8414,
#  5019,
#  5201,
#  7130,
#  5,
#  6220,
#  2835,
#  7122,
#  3173,
#  6073,
#  5380,
#  7498,
#  5001,
#  5694,
#  5273,
#  1720,
#  2573,
#  5168,
#  2098,
#  10554,
#  3200,
#  7759,
#  10839,
#  2689,
#  7617,
#  8790,
#  6246,
#  3683,
#  7711,
#  1852,
#  7991,
#  1535,
#  20,
#  8945,
#  5938,
#  8195,
#  3785,
#  7981,
#  7750,
#  2934,
#  5930,
#  8266,
#  4622,
#  3295,
#  1382,
#  2277,
#  1066,
#  4498,
#  3816,
#  10195,
#  775,
#  4702,
#  8732,
#  4765,
#  5264,
#  5233,
#  4511,
#  6799,
#  5365,
#  9774,
#  1467,
#  5729,
#  1138,
#  8155,
#  6591,
#  8409,
#  1395,
#  3729,
#  10013,
#  2536,
#  9501,
#  4557,
#  7191,
#  6638,
#  9009,
#  10297,
#  5165,
#  7950,
#  8635,
#  7605,
#  8986,
#  3793,
#  4922,
#  2172,
#  4978,
#  1175,
#  2540,
#  502,
#  10800,
#  3131,
#  2743,
#  3923,
#  10272,
#  1733,
#  2097,
#  1610,
#  3192,
#  2209,
#  6414,
#  6759,
#  2064,
#  8238,
#  269,
#  10358,
#  5858,
#  8699,
#  3468,
#  6561,
#  3297,
#  3459,
#  10613,
#  9301,
#  3613,
#  10054,
#  446,
#  4164,
#  1816,
#  9342,
#  10027,
#  3070,
#  8533,
#  1309,
#  6222,
#  8971,
#  5544,
#  9709,
#  7643,
#  1817,
#  6918,
#  10853,
#  4451,
#  3408,
#  4769,
#  8235,
#  1750,
#  9059,
#  5653,
#  5561,
#  6450,
#  6950,
#  9766,
#  8802,
#  9559,
#  8766,
#  4330,
#  2361,
#  654,
#  9416,
#  864,
#  1419,
#  9347,
#  1298,
#  965,
#  6535,
#  10333,
#  4235,
#  6254,
#  3977,
#  2933,
#  5126,
#  2702,
#  4844,
#  2727,
#  4140,
#  5270,
#  4726,
#  2296,
#  3587,
#  8949,
#  ...]

# %%
test['x'] = test['text_prep'].apply(lambda x: model.infer_vector(x))
test
# Out:
#       keyword location                                               text  \
# id
# 0         NaN      NaN                 Just happened a terrible car crash
# 2         NaN      NaN  Heard about #earthquake is different cities, s...
# 3         NaN      NaN  there is a forest fire at spot pond, geese are...
# 9         NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 11        NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan
# ...       ...      ...                                                ...
# 10861     NaN      NaN  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 10865     NaN      NaN  Storm in RI worse than last hurricane. My city...
# 10868     NaN      NaN  Green Line derailment in Chicago http://t.co/U...
# 10874     NaN      NaN  MEG issues Hazardous Weather Outlook (HWO) htt...
# 10875     NaN      NaN  #CityofCalgary has activated its Municipal Eme...
#
#                                                text_prep  \
# id
# 0                 [just, happened, terrible, car, crash]
# 2      [heard, earthquake, different, cities, stay, s...
# 3      [forest, fire, spot, pond, geese, fleeing, acr...
# 9             [apocalypse, lighting, spokane, wildfires]
# 11         [typhoon, soudelor, kills, 28, china, taiwan]
# ...                                                  ...
# 10861  [earthquake, safety, los, angeles, safety, fas...
# 10865  [storm, ri, worse, last, hurricane, my, city, ...
# 10868  [green, line, derailment, chicago, http, tcout...
# 10874  [meg, issues, hazardous, weather, outlook, hwo...
# 10875  [cityofcalgary, activated, municipal, emergenc...
#
#                                                        x
# id
# 0      [-0.0053129955, 0.005087275, 0.0034982103, 0.0...
# 2      [-0.010875889, 0.0075846906, 0.005635406, 0.00...
# 3      [-0.0034923425, 0.0014190368, 0.0035825502, 0....
# 9      [-0.003320934, 0.003930992, 0.0015746179, 0.00...
# 11     [-0.009974931, 0.0058606705, 0.00433252, 0.006...
# ...                                                  ...
# 10861  [-0.0026034634, 0.0032635338, 0.00012493004, -...
# 10865  [-0.015165645, 0.013136677, 0.009227871, 0.007...
# 10868  [-0.0071160384, 0.0038670176, 0.0033742343, 0....
# 10874  [-0.002654015, 0.0022429759, 0.0034386967, 0.0...
# 10875  [-0.0066537512, 0.0059544626, 0.004331155, 0.0...
#
# [3263 rows x 5 columns]

# %%
train.head()
# Out:
#           keyword                  location  \
# id
# 7761       police                       NaN
# 7670        panic  Palm Bay, FL (Kissimmee)
# 583         arson                    EARTH
# 7689        panic                    Narnia
# 9888  traumatised                Londonstan
#
#                                                    text  target  \
# id
# 7761  Police expand search for missing pregnant woma...       0
# 7670  Panic over: Patient in Alabama tests negative ...       1
# 583   Owner of Chicago-Area Gay Bar Admits to Arson ...       0
# 7689  I added a video to a @YouTube playlist http://...       0
# 9888  ÛÏ@_keits: @LIVA_GOTTA get a gold chain you'l...       0
#
#                                               text_prep  \
# id
# 7761  [police, expand, search, missing, pregnant, wo...
# 7670  [panic, patient, alabama, tests, negative, ebo...
# 583   [owner, chicagoarea, gay, bar, admits, arson, ...
# 7689  [i, added, video, youtube, playlist, http, tco...
# 9888  [keits, livagotta, get, gold, chain, ll, under...
#
#                                                       x
# id
# 7761  [-0.007308758, 0.005901744, 0.0036629573, 0.00...
# 7670  [-0.019752247, 0.014266182, 0.010357015, 0.009...
# 583   [-0.010665309, 0.010349484, 0.00755486, 0.0057...
# 7689  [-0.0047078, 0.004301085, 0.004400423, 0.00467...
# 9888  [-0.011215143, 0.008989504, 0.0096160155, 0.00...

# %%
train.shape[0]
# Out:
# 7613

# %%
# x_test[0:2]
train.target.unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# <h1>Starting with the SVM</h1>

# %%
from sklearn import svm

#model = svm.SVC(kernel= 'poly', gamma= 3, random_state= 0, C= 0.8)
model = svm.SVC()

# %%
model.fit(train.x.to_list(), train.target.to_list())
# Out:
# SVC()

# %%
item = train.x[10]
label = train.target[10]
print(label)
# Out:
# 1

# %%
model.predict([item])
#model.classes_
# Out:
# array([0])

# %%
def stats(model, X,y):
    preds = model.predict(X)
    TP=0; FP=0; TN=0; FN=0

    for i in range(len(preds)):
        if preds[i] == 1 and y[i] == 1:
            TP += 1
        elif preds[i] == 0 and y[i] == 0:
            TN += 1
        elif preds[i] == 0 and y[i] == 1:
            FN += 1
        elif preds[i] == 1 and y[i] == 0:
            FP += 1
            
    acc = (TP+TN) / (TP+TN+FP+FN) if (TP+TN+FP+FN) > 0 else 0
    rec = (TP) / (TP+FN) if (TP+FN) > 0 else 0
    pre = (TP) / (TP+FP) if (TP+FP) > 0 else 0
    print('='*26)
    print('|  acc   |  rec  |  pre  |')
    print('-'*26)
    print(f"| {round(acc*100, 2)}% | {round(rec*100, 2)}% | {round(pre*100, 2)}% |")
    print('='*26)
    return TP, FP, TN, FN

#stats(model, train.x.to_list(), train.target.to_list())

# %%
def compare_stats(preds, y):
    TP=0; FP=0; TN=0; FN=0

    for i in range(len(preds)):
        if preds[i] == 1 and y[i] == 1:
            TP += 1
        elif preds[i] == 0 and y[i] == 0:
            TN += 1
        elif preds[i] == 0 and y[i] == 1:
            FN += 1
        elif preds[i] == 1 and y[i] == 0:
            FP += 1
            
    acc = (TP+TN) / (TP+TN+FP+FN) if (TP+TN+FP+FN) > 0 else 0
    rec = (TP) / (TP+FN) if (TP+FN) > 0 else 0
    pre = (TP) / (TP+FP) if (TP+FP) > 0 else 0
    print('='*26)
    print('|  acc   |  rec  |  pre  |')
    print('-'*26)
    print(f"| {round(acc*100, 2)}% | {round(rec*100, 2)}% | {round(pre*100, 2)}% |")
    print('='*26)
    return TP, FP, TN, FN

# stats(model, train.x.to_list(), train.target.to_list())

# %%
set(model.predict(train.x.to_list()))
# Out:
# {0, 1}

# %%
pred = model.predict(test.x.to_list())

# %%
set(pred)
# Out:
# {0}

# %%
a = pred.tolist()
pd.DataFrame(data={'id': test.index.to_list(), 'target': a}).to_csv('submission_SVM_doc2vec.csv', index=False)

# %% [markdown]
# <h1>Feature Engineering</h1>

# %%
train.head()
# Out:
#           keyword                  location  \
# id
# 7761       police                       NaN
# 7670        panic  Palm Bay, FL (Kissimmee)
# 583         arson                    EARTH
# 7689        panic                    Narnia
# 9888  traumatised                Londonstan
#
#                                                    text  target  \
# id
# 7761  Police expand search for missing pregnant woma...       0
# 7670  Panic over: Patient in Alabama tests negative ...       1
# 583   Owner of Chicago-Area Gay Bar Admits to Arson ...       0
# 7689  I added a video to a @YouTube playlist http://...       0
# 9888  ÛÏ@_keits: @LIVA_GOTTA get a gold chain you'l...       0
#
#                                               text_prep  \
# id
# 7761  [police, expand, search, missing, pregnant, wo...
# 7670  [panic, patient, alabama, tests, negative, ebo...
# 583   [owner, chicagoarea, gay, bar, admits, arson, ...
# 7689  [i, added, video, youtube, playlist, http, tco...
# 9888  [keits, livagotta, get, gold, chain, ll, under...
#
#                                                       x
# id
# 7761  [-0.007308758, 0.005901744, 0.0036629573, 0.00...
# 7670  [-0.019752247, 0.014266182, 0.010357015, 0.009...
# 583   [-0.010665309, 0.010349484, 0.00755486, 0.0057...
# 7689  [-0.0047078, 0.004301085, 0.004400423, 0.00467...
# 9888  [-0.011215143, 0.008989504, 0.0096160155, 0.00...

# %%
train['polarity'] = train['text'].apply(lambda text: TextBlob(text).sentiment.polarity)
train['subjectivity'] = train['text'].apply(lambda text: TextBlob(text).sentiment.subjectivity)
train.head()
# Out:
# <ipython-input-50-f39b078bfcf3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['polarity'] = train['text'].apply(lambda text: TextBlob(text).sentiment.polarity)
# <ipython-input-50-f39b078bfcf3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['subjectivity'] = train['text'].apply(lambda text: TextBlob(text).sentiment.subjectivity)
#           keyword                  location  \
# id
# 7761       police                       NaN
# 7670        panic  Palm Bay, FL (Kissimmee)
# 583         arson                    EARTH
# 7689        panic                    Narnia
# 9888  traumatised                Londonstan
#
#                                                    text  target  \
# id
# 7761  Police expand search for missing pregnant woma...       0
# 7670  Panic over: Patient in Alabama tests negative ...       1
# 583   Owner of Chicago-Area Gay Bar Admits to Arson ...       0
# 7689  I added a video to a @YouTube playlist http://...       0
# 9888  ÛÏ@_keits: @LIVA_GOTTA get a gold chain you'l...       0
#
#                                               text_prep  \
# id
# 7761  [police, expand, search, missing, pregnant, wo...
# 7670  [panic, patient, alabama, tests, negative, ebo...
# 583   [owner, chicagoarea, gay, bar, admits, arson, ...
# 7689  [i, added, video, youtube, playlist, http, tco...
# 9888  [keits, livagotta, get, gold, chain, ll, under...
#
#                                                       x  \
# id
# 7761  [-0.007308758, 0.005901744, 0.0036629573, 0.00...
# 7670  [-0.019752247, 0.014266182, 0.010357015, 0.009...
# 583   [-0.010665309, 0.010349484, 0.00755486, 0.0057...
# 7689  [-0.0047078, 0.004301085, 0.004400423, 0.00467...
# 9888  [-0.011215143, 0.008989504, 0.0096160155, 0.00...
#
#                                      sentiment  polarity  subjectivity
# id
# 7761              (0.06666666666666665, 0.275)  0.066667      0.275000
# 7670                               (-0.3, 0.4) -0.300000      0.400000
# 583   (0.4166666666666667, 0.5833333333333334)  0.416667      0.583333
# 7689                              (0.35, 0.55)  0.350000      0.550000
# 9888                               (-0.2, 0.3) -0.200000      0.300000

# %% [markdown]
# <h1>SVM + BoW</h1>

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.svm import SVC

# %%
from sklearn.pipeline import Pipeline
text_clf = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('svm', SVC()),
])

# %%
X_train = pd.read_csv(DATA_PATH+'train.csv', index_col= 0)
X_test = pd.read_csv(DATA_PATH+'test.csv', index_col= 0)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_train.text, X_train.target, test_size=0.10)

# %%
count_vect = CountVectorizer(max_features= 4400)
X_train_counts = count_vect.fit_transform(X_train)
X_train_counts.shape
# Out:
# (6851, 4400)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (6851, 4400)

# %%
X_train_tfidf[0]
# Out:
# <1x4400 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>

# %%
from sklearn.naive_bayes import MultinomialNB
#clf = MultinomialNB().fit(X_train_tfidf, X_train.target)
clf = SVC().fit(X_train_tfidf, Y_train)

# %%
# validation
count_vect = CountVectorizer(max_features= 4400)
X_valid_counts = count_vect.fit_transform(X_valid)
tfidf_transformer = TfidfTransformer()
X_valid_tfidf = tfidf_transformer.fit_transform(X_valid_counts)
X_valid_tfidf.shape
# Out:
# (762, 4400)

# %%
pred_svm = clf.predict(X_valid_tfidf)

# %%
set(pred_svm)
# Out:
# {0, 1}

# %%
compare_stats(pred_svm,Y_valid.to_list())
# Out:
# ==========================
# |  acc   |  rec  |  pre  |
# --------------------------
# | 52.36% | 8.1% | 46.03% |
# ==========================
# (29, 34, 370, 329)

# %%
X_test
# Out:
#       keyword location                                               text
# id
# 0         NaN      NaN                 Just happened a terrible car crash
# 2         NaN      NaN  Heard about #earthquake is different cities, s...
# 3         NaN      NaN  there is a forest fire at spot pond, geese are...
# 9         NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 11        NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan
# ...       ...      ...                                                ...
# 10861     NaN      NaN  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 10865     NaN      NaN  Storm in RI worse than last hurricane. My city...
# 10868     NaN      NaN  Green Line derailment in Chicago http://t.co/U...
# 10874     NaN      NaN  MEG issues Hazardous Weather Outlook (HWO) htt...
# 10875     NaN      NaN  #CityofCalgary has activated its Municipal Eme...
#
# [3263 rows x 3 columns]

# %%
ind = X_test.index.to_list()
ind_t = X_train.index.to_list()

# %%
docs_new = X_test.text.to_list()
X_new_counts = count_vect.transform(docs_new)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

pred = clf.predict(X_new_tfidf)
pred
# Out:
# array([0, 0, 0, ..., 1, 1, 0], dtype=int64)

# %%
pred_svm_t = pred.tolist()

# %%
solution = pd.DataFrame(data= {'id': ind, 'target': pred_svm_t})

# %%
solution.head()
# Out:
#    id  target
# 0   0       0
# 1   2       0
# 2   3       0
# 3   9       0
# 4  11       0

# %%
#solution.to_csv('submission_SVC.csv',index= False)

# %% [markdown]
# <h1>SVM + BoW + Including Sentiment features</h1>

# %%
# pipelining the predictions in one svm
from sklearn.pipeline import FeatureUnion
from sklearn.preprocessing import FunctionTransformer
import numpy as np

# %%
train.head(3)
# Out:
#      keyword                  location  \
# id
# 7761  police                       NaN
# 7670   panic  Palm Bay, FL (Kissimmee)
# 583    arson                    EARTH
#
#                                                    text  target  \
# id
# 7761  Police expand search for missing pregnant woma...       0
# 7670  Panic over: Patient in Alabama tests negative ...       1
# 583   Owner of Chicago-Area Gay Bar Admits to Arson ...       0
#
#                                               text_prep  \
# id
# 7761  [police, expand, search, missing, pregnant, wo...
# 7670  [panic, patient, alabama, tests, negative, ebo...
# 583   [owner, chicagoarea, gay, bar, admits, arson, ...
#
#                                                       x  \
# id
# 7761  [-0.007308758, 0.005901744, 0.0036629573, 0.00...
# 7670  [-0.019752247, 0.014266182, 0.010357015, 0.009...
# 583   [-0.010665309, 0.010349484, 0.00755486, 0.0057...
#
#                                      sentiment  polarity  subjectivity
# id
# 7761              (0.06666666666666665, 0.275)  0.066667      0.275000
# 7670                               (-0.3, 0.4) -0.300000      0.400000
# 583   (0.4166666666666667, 0.5833333333333334)  0.416667      0.583333

# %%
# Classifier data
svm_train = train.text
svm_train_y = train.target.to_list()

svm_train, svm_valid, svm_train_y, svm_valid_y = train_test_split(svm_train, svm_train_y,test_size=0.10)

# New features
svm_polarity = np.array(train.polarity.to_list())
svm_subjectivity = np.array(train.subjectivity.to_list())

# %%
len(svm_valid)
# Out:
# 762

# %%
def get_polarity(x):
    return np.array([TextBlob(t).sentiment.polarity for t in x]).reshape(-1, 1)

def get_subjectivity(x):
    return np.array([TextBlob(t).sentiment.subjectivity for t in x]).reshape(-1, 1)

svm_classifier = Pipeline([
    ('features', FeatureUnion([
        ('pola', Pipeline([
            ('polarity', FunctionTransformer(get_polarity, validate=False))
        ])),
        ('subj', Pipeline([
            ('subjectivity', FunctionTransformer(get_subjectivity, validate=False))
        ])),
        
        ('text', Pipeline([
            ('vect', CountVectorizer(max_features= 12000)),
            ('tfidf', TfidfTransformer()),
        ])),
    ])),
    ('svm', SVC(C=0.8))
])

# %%
svm_classifier.fit(svm_train, svm_train_y)
# Out:
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('pola',
#                                                  Pipeline(steps=[('polarity',
#                                                                   FunctionTransformer(func=<function get_polarity at 0x00000225AD64C430>))])),
#                                                 ('subj',
#                                                  Pipeline(steps=[('subjectivity',
#                                                                   FunctionTransformer(func=<function get_subjectivity at 0x00000225AD64C040>))])),
#                                                 ('text',
#                                                  Pipeline(steps=[('vect',
#                                                                   CountVectorizer(max_features=12000)),
#                                                                  ('tfidf',
#                                                                   TfidfTransformer())]))])),
#                 ('svm', SVC(C=0.8))])

# %%
k = svm_classifier.predict(svm_valid)

# %%
compare_stats(k, svm_valid_y)
# Out:
# ==========================
# |  acc   |  rec  |  pre  |
# --------------------------
# | 80.58% | 66.04% | 84.0% |
# ==========================
# (210, 40, 404, 108)

# %% [markdown]
# <h1>XGBoost</h1>

# %%
#%pip install xgboost
from xgboost import XGBClassifier

# %%
X_train = pd.read_csv(DATA_PATH+'train.csv', index_col= 0)
X_test = pd.read_csv(DATA_PATH+'test.csv', index_col= 0)
X_train
# Out:
#       keyword location                                               text  \
# id
# 1         NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 4         NaN      NaN             Forest fire near La Ronge Sask. Canada
# 5         NaN      NaN  All residents asked to 'shelter in place' are ...
# 6         NaN      NaN  13,000 people receive #wildfires evacuation or...
# 7         NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
# ...       ...      ...                                                ...
# 10869     NaN      NaN  Two giant cranes holding a bridge collapse int...
# 10870     NaN      NaN  @aria_ahrary @TheTawniest The out of control w...
# 10871     NaN      NaN  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# 10872     NaN      NaN  Police investigating after an e-bike collided ...
# 10873     NaN      NaN  The Latest: More Homes Razed by Northern Calif...
#
#        target
# id
# 1           1
# 4           1
# 5           1
# 6           1
# 7           1
# ...       ...
# 10869       1
# 10870       1
# 10871       1
# 10872       1
# 10873       1
#
# [7613 rows x 4 columns]

# %%
# xgb = XGBClassifier(random_state=42, seed=2, colsample_bytree=0.5, subsample=0.8) #87.17% | 77.16% | 91.65% 
#xgb = XGBClassifier(random_state=42, seed=2, colsample_bytree=0.5, subsample=1) #87.8% | 76.77% | 93.69% 
#xgb = XGBClassifier(random_state=42, seed=2, colsample_bytree=0.5, subsample=1, max_depth= 10) # 91.5% | 83.22% | 96.52%
#xgb = XGBClassifier(random_state=42, seed=2, colsample_bytree=0.5, subsample=0.9, max_depth= 50) # 98.29% | 96.97% | 99.03%
xgb = XGBClassifier(random_state=42, seed=2, colsample_bytree=0.7, subsample=0.9, max_depth= 100)

# %%
xgb.fit(X_train_tfidf, X_train.target)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.7, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=100,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=2,
#               subsample=0.9, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
pred_xgb = xgb.predict(X_train_tfidf)
stats(xgb, X_train_tfidf,X_train.target.to_list())
# SVM: | 95.82% | 91.78% | 98.39% |
# Out:
# ==========================
# |  acc   |  rec  |  pre  |
# --------------------------
# | 98.5% | 97.68% | 98.82% |
# ==========================
# (3195, 38, 4304, 76)

# %%
docs_new = X_test.text.to_list()
X_new_counts = count_vect.transform(docs_new)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

pred_xgb_t = xgb.predict(X_new_tfidf).tolist()
solution = pd.DataFrame(data= {'id': ind, 'target': pred_xgb_t})

# %%
solution.to_csv('submission_GDB.csv',index= False)

# %% [markdown]
# <h1>Multinomial</h1>

# %%
from sklearn.naive_bayes import MultinomialNB
m = MultinomialNB().fit(X_train_tfidf, X_train.target)

# %%
pred_m = m.predict(X_train_tfidf)
stats(m, X_train_tfidf,X_train.target.to_list())
# SVM: | 95.82% | 91.78% | 98.39% |
# Out:
# ==========================
# |  acc   |  rec  |  pre  |
# --------------------------
# | 86.77% | 73.77% | 94.18% |
# ==========================
# (2413, 149, 4193, 858)

# %%
docs_new = X_test.text.to_list()
X_new_counts = count_vect.transform(docs_new)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

pred_m_t = m.predict(X_new_tfidf).tolist()
solution = pd.DataFrame(data= {'id': ind, 'target': pred_m_t})
solution.to_csv('submission_Multinomial.csv',index= False)

# %% [markdown]
# <h1> Boosting </h1>

# %%
#df = pd.DataFrame(data= {'id': ind_t,'svm': pred_svm, 'multi': pred_m, 'xgb': pred_xgb})
df = pd.DataFrame(data= {'id': ind,'svm': pred_svm_t, 'multi': pred_m_t, 'xgb': pred_xgb_t})
print(len(pred_m))
print(len(pred_xgb))
print(len(pred_svm))
# Out:
# 7613
# 7613
# 7613

# %%
df.head(3)
# Out:
#    id  svm  multi  xgb
# 0   0    1      1    1
# 1   2    0      0    0
# 2   3    1      1    1

# %%
df['pred'] = df.apply(lambda x: 1 if(x.svm + x.multi + x.xgb) > 1 else 0, axis= 1)
df.head()
# Out:
#    id  svm  multi  xgb  pred
# 0   0    1      1    1     1
# 1   2    0      0    0     0
# 2   3    1      1    1     1
# 3   9    0      1    0     0
# 4  11    1      1    0     1

# %%
compare_stats(df.pred.to_list(), ind_t)
# Out:
# ==========================
# |  acc   |  rec  |  pre  |
# --------------------------
# | 100.0% | 100.0% | 100.0% |
# ==========================
# (1, 0, 0, 0)

# %%
# lets use boosting to predict 
solution = pd.DataFrame(data= {'id': ind, 'target': df.pred.to_list()})
solution.to_csv('submission_bosted.csv',index= False)
